# %%
import numpy as np

load csv("/path/to/metadafile.csv")
columns = ["bz offset time", 'vx']

load csv("/path/to/orbit-params.csv")
columns = [omni_bsn_position, artemis_psn]

sc_sep = []
for i in range(len(omni_bsn_postiton)-60):
    sc_sep.append(np.mean(artemis_psn[i:i+60]) - np.mean(omni_bsn_postiton[i:i+60]))

# %%
expected_offset = []
    for j in range(len(vx)):
        expected_offset.append(sc_sep[j] / vx[j])
